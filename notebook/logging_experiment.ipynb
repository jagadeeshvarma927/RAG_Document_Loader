# %%
print("all ok")
# Out:
# all ok

# %%
import logging
import os
from datetime import datetime

# %%
logs_dir = os.path.join(os.getcwd(), "logs")

# %%
os.makedirs(logs_dir, exist_ok=True)

# %%
log_file = f"{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.log"

# %%
log_file
# Out:
# '2025-07-26_14-42-56.log'

# %% [markdown]
# ### today
#
# ### with todays date log file will be created in the logs directory
# ### Tommorrow
#
# ### with tomorrow's date log file will be created in the logs directory

# %%
LOG_FILE_PATH = os.path.join(logs_dir, log_file)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
        format='"[%(asctime)s] %(levelname)s %(name)s (line %(lineno)d): %(message)s"',
    level=logging.INFO,

)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
logger = logging.getLogger("DocumentPortal")

# %%
logger.info("This is an info message")

# %% [markdown]
# ### Struct Log is used for structerin the logging output

# %%
import structlog

logger = structlog.get_logger()

# %%
logger.info("This is an info message with structlog")
# Out:
# 2025-07-26 16:23:44 [info     ] This is an info message with structlog
